# %% [markdown]
# # Identifying the sampling level of each housing characteristic
#
# In this notebook, I am trying to put together a hierarchical graph visualization that shows the dependencies and when they will be sampled.
#
# ## Import Modules

# %%
import numpy as np
import pandas as pd
from IPython.display import display
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout
from nxpd import draw

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# Load
adj_df = pd.read_csv('../dependencyWheels/adjacency matrix.csv',index_col=0)

# Create Graph
G = nx.from_pandas_adjacency(adj_df,nx.DiGraph())
n_nodes = len(G.nodes)
n_edges = len(G.edges)
node_names = adj_df.columns.values
longest_path_len = nx.dag_longest_path_length(G)
edges_org = G.edges
print(nx.info(G))
print('Longest path length:\t %d' % longest_path_len)

# Reset index for convienience
adj_df.reset_index(inplace=True,drop=True)
# Out:
# Name:
# Type: DiGraph
# Number of nodes: 83
# Number of edges: 145
# Average in degree:   1.7470
# Average out degree:   1.7470
# Longest path length:	 8

# %% [markdown]
# ## Identify level of housing characteristics

# %%
# Initialize node level values
level = np.zeros_like(adj_df[adj_df.columns[0]])

# Iterate over nodes up to the longest path length
for j in range(int(longest_path_len)):
    # For each housing characteristic node
    for i in range(n_nodes):
        # Get the index of the dependencies
        column_name = adj_df.columns[i]
        dependencies = np.where(adj_df[column_name] == 1)[0]
        
        #If there are dependencies
        if len(dependencies) > 0:
            # Get the level of the dependencies
            dependency_levels = level[dependencies]
            
            # Identify the maximum level of the dependencies
            max_level = np.max(dependency_levels)
            
            # This node's level must be one greater than the max level
            level[i] = max_level + 1

# Print housing characteristics grouped by levels
for i in range(int(longest_path_len)):
    idx = np.where(level == i)[0]
    print("Level: %d" % i)
    for j in range(len(idx)):
        print("  %s" % node_names[idx[j]])
    print()
# Out:
# Level: 0
#   Bathroom Spot Vent Hour
#   Ceiling Fan
#   Days Shifted
#   Dehumidifier
#   Door Area
#   Doors
#   Eaves
#   Geometry Building Type FPL
#   Insulation Finished Roof
#   Lighting
#   Mechanical Ventilation
#   Misc Extra Refrigerator
#   Misc Freezer
#   Misc Gas Fireplace
#   Misc Gas Grill
#   Misc Gas Lighting
#   Misc Hot Tub Spa
#   Misc Pool
#   Misc Well Pump
#   Natural Ventilation
#   Occupants
#   Overhangs
#   PV
#   Range Spot Vent Hour
#   Roof Material
#   Solar Hot Water
#   Usage Level
#   Window Areas
#
# Level: 1
#   Clothes Washer
#   Dishwasher
#   Geometry Building Type
#   Hot Water Fixtures
#   Location EPW
#   Plug Loads
#   Refrigerator
#
# Level: 2
#   Cooling Setpoint
#   Geometry Foundation Type
#   Geometry Is Multifamily Low Rise
#   Geometry Perimeter Footprint Ratio
#   Heating Setpoint
#   Location Region
#   Vintage FPL
#
# Level: 3
#   Geometry House Size
#   Geometry Nearest Neighbor LeftRight
#   Geometry Shared Walls MF
#   Geometry Shared Walls SFA
#   Heating Fuel
#   Orientation
#   Vintage
#
# Level: 4
#   Clothes Dryer
#   Cooking Range
#   Ducts
#   Geometry Building  Number Units HL
#   Geometry Building Floors
#   Geometry Garage
#   Geometry Unit Stories MF
#   Geometry Unit Stories SF
#   Hot Water Distribution
#   HVAC System Is Shared
#   Insulation Crawlspace
#   Insulation Finished Basement
#   Insulation Interzonal Floor
#   Insulation Pier Beam
#   Insulation Slab
#   Insulation Unfinished Attic
#   Insulation Unfinished Basement
#   Insulation Wall
#   Water Heater
#   Windows
#
# Level: 5
#   Geometry Building Number Units MF
#   Geometry Building Number Units SFA
#   HVAC System Is Heatpump
#   Infiltration
#
# Level: 6
#   HVAC System Cooling
#   HVAC System Heating Electricity
#   HVAC System Heating Fuel Oil
#   HVAC System Heating Natural Gas
#   HVAC System Heating None
#   HVAC System Heating Other Fuel
#   HVAC System Heating Propane
#   HVAC System Heatpump
#
# Level: 7
#   HVAC System Cooling Type

# %% [markdown]
# ## Identify edges that jump more than 1 level

# %%
jump_edges = list()
edges_new = list()
for edge in G.edges:
    idx_in = np.where(edge[0] == node_names)[0][0]
    idx_out = np.where(edge[1] == node_names)[0][0]

    jump = int(np.fabs(level[idx_in] - level[idx_out]))
    if jump > 1:
        jump_edges.append(edge)
        print(edge)
        print('  Total Jump: %d' % jump)
        print('  Start,End: %d,%d' % (level[idx_in],level[idx_out]) )
        print('  Paths:')
        for path in nx.all_simple_paths(G,node_names[idx_in],node_names[idx_out]):
            for node in path:
                print("   ",node)
            print()
        print()
    else:
        edges_new.append(edge)

print(len(jump_edges))
# Out:
# ('Geometry Building Type FPL', 'Geometry Building  Number Units HL')
#   Total Jump: 4
#   Start,End: 0,4
#   Paths:
#     Geometry Building Type FPL
#     Geometry Building  Number Units HL
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Vintage
#     Geometry Building  Number Units HL
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage
#     Geometry Building  Number Units HL
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Vintage
#     Geometry Building  Number Units HL
#
#
# ('Geometry Building Type FPL', 'Geometry Building Number Units MF')
#   Total Jump: 5
#   Start,End: 0,5
#   Paths:
#     Geometry Building Type FPL
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Geometry Building Type
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Location EPW
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units MF
#
#
# ('Geometry Building Type FPL', 'Geometry Building Number Units SFA')
#   Total Jump: 5
#   Start,End: 0,5
#   Paths:
#     Geometry Building Type FPL
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Geometry Building Type
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Location EPW
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Geometry House Size
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Vintage
#     Geometry Building Floors
#     Geometry Building Number Units SFA
#
#
# ('Geometry Building Type FPL', 'Geometry House Size')
#   Total Jump: 3
#   Start,End: 0,3
#   Paths:
#     Geometry Building Type FPL
#     Geometry House Size
#
#     Geometry Building Type FPL
#     Location EPW
#     Geometry House Size
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Geometry House Size
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Geometry House Size
#
#
# ('Geometry Building Type FPL', 'Heating Fuel')
#   Total Jump: 3
#   Start,End: 0,3
#   Paths:
#     Geometry Building Type FPL
#     Heating Fuel
#
#     Geometry Building Type FPL
#     Location EPW
#     Heating Fuel
#
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#     Heating Fuel
#
#     Geometry Building Type FPL
#     Vintage FPL
#     Heating Fuel
#
#
# ('Geometry Building Type FPL', 'Vintage FPL')
#   Total Jump: 2
#   Start,End: 0,2
#   Paths:
#     Geometry Building Type FPL
#     Location EPW
#     Vintage FPL
#
#     Geometry Building Type FPL
#     Vintage FPL
#
#
# ('Geometry Building Type', 'Ducts')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Ducts
#
#     Geometry Building Type
#     Geometry Foundation Type
#     Ducts
#
#
# ('Geometry Building Type', 'Geometry Building Floors')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Building Floors
#
#
# ('Geometry Building Type', 'Geometry Garage')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Garage
#
#
# ('Geometry Building Type', 'Geometry Unit Stories MF')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Unit Stories MF
#
#
# ('Geometry Building Type', 'Geometry Unit Stories SF')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Unit Stories SF
#
#
# ('Geometry Building Type', 'HVAC System Is Shared')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     HVAC System Is Shared
#
#
# ('Geometry Building Type', 'HVAC System Shared')
#   Total Jump: 7
#   Start,End: 1,8
#   Paths:
#     Geometry Building Type
#     HVAC System Is Shared
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Geometry Building Type
#     HVAC System Is Shared
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Geometry Building Type
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Geometry Building Type
#     HVAC System Is Shared
#     HVAC System Shared
#
#     Geometry Building Type
#     HVAC System Shared
#
#
# ('Geometry Building Type', 'Infiltration')
#   Total Jump: 4
#   Start,End: 1,5
#   Paths:
#     Geometry Building Type
#     Geometry Building Floors
#     Infiltration
#
#     Geometry Building Type
#     Infiltration
#
#
# ('Geometry Building Type', 'Insulation Crawlspace')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Foundation Type
#     Insulation Crawlspace
#
#     Geometry Building Type
#     Insulation Crawlspace
#
#
# ('Geometry Building Type', 'Insulation Finished Basement')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Foundation Type
#     Insulation Finished Basement
#
#     Geometry Building Type
#     Insulation Finished Basement
#
#
# ('Geometry Building Type', 'Insulation Pier Beam')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Foundation Type
#     Insulation Pier Beam
#
#     Geometry Building Type
#     Insulation Pier Beam
#
#
# ('Geometry Building Type', 'Insulation Slab')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Foundation Type
#     Insulation Slab
#
#     Geometry Building Type
#     Insulation Slab
#
#
# ('Geometry Building Type', 'Insulation Unfinished Basement')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Geometry Foundation Type
#     Insulation Unfinished Basement
#
#     Geometry Building Type
#     Insulation Unfinished Basement
#
#
# ('Geometry Building Type', 'Windows')
#   Total Jump: 3
#   Start,End: 1,4
#   Paths:
#     Geometry Building Type
#     Windows
#
#
# ('Geometry Foundation Type', 'Ducts')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Ducts
#
#
# ('Geometry Foundation Type', 'Insulation Crawlspace')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Insulation Crawlspace
#
#
# ('Geometry Foundation Type', 'Insulation Finished Basement')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Insulation Finished Basement
#
#
# ('Geometry Foundation Type', 'Insulation Pier Beam')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Insulation Pier Beam
#
#
# ('Geometry Foundation Type', 'Insulation Slab')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Insulation Slab
#
#
# ('Geometry Foundation Type', 'Insulation Unfinished Basement')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Geometry Foundation Type
#     Insulation Unfinished Basement
#
#
# ('Geometry House Size', 'Infiltration')
#   Total Jump: 2
#   Start,End: 3,5
#   Paths:
#     Geometry House Size
#     Geometry Building Floors
#     Infiltration
#
#     Geometry House Size
#     Infiltration
#
#
# ('Heating Fuel', 'HVAC System Cooling')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Cooling
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Cooling
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#
# ('Heating Fuel', 'HVAC System Heating Electricity')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating Electricity
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Heating Electricity
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#
# ('Heating Fuel', 'HVAC System Heating Fuel Oil')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating Fuel Oil
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Heating Fuel Oil
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#
# ('Heating Fuel', 'HVAC System Heating Natural Gas')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating Natural Gas
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Heating Natural Gas
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#
# ('Heating Fuel', 'HVAC System Heating None')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating None
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating None
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating None
#
#
# ('Heating Fuel', 'HVAC System Heating Other Fuel')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating Other Fuel
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating Other Fuel
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Other Fuel
#
#
# ('Heating Fuel', 'HVAC System Heating Propane')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heating Propane
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Heating Propane
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#
# ('Heating Fuel', 'HVAC System Heatpump')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Heating Fuel
#     HVAC System Heatpump
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Heatpump
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heatpump
#
#
# ('Heating Fuel', 'HVAC System Is Heatpump')
#   Total Jump: 2
#   Start,End: 3,5
#   Paths:
#     Heating Fuel
#     HVAC System Is Heatpump
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#
#
# ('Heating Fuel', 'HVAC System Shared')
#   Total Jump: 5
#   Start,End: 3,8
#   Paths:
#     Heating Fuel
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Is Shared
#     HVAC System Shared
#
#     Heating Fuel
#     HVAC System Shared
#
#
# ('HVAC System Is Shared', 'HVAC System Cooling Type')
#   Total Jump: 3
#   Start,End: 4,7
#   Paths:
#     HVAC System Is Shared
#     HVAC System Cooling Type
#
#     HVAC System Is Shared
#     HVAC System Cooling
#     HVAC System Cooling Type
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#
#
# ('HVAC System Is Shared', 'HVAC System Cooling')
#   Total Jump: 2
#   Start,End: 4,6
#   Paths:
#     HVAC System Is Shared
#     HVAC System Cooling
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#
# ('HVAC System Is Shared', 'HVAC System Heating Electricity')
#   Total Jump: 2
#   Start,End: 4,6
#   Paths:
#     HVAC System Is Shared
#     HVAC System Heating Electricity
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#
# ('HVAC System Is Shared', 'HVAC System Heating Fuel Oil')
#   Total Jump: 2
#   Start,End: 4,6
#   Paths:
#     HVAC System Is Shared
#     HVAC System Heating Fuel Oil
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#
# ('HVAC System Is Shared', 'HVAC System Heating Natural Gas')
#   Total Jump: 2
#   Start,End: 4,6
#   Paths:
#     HVAC System Is Shared
#     HVAC System Heating Natural Gas
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#
# ('HVAC System Is Shared', 'HVAC System Heating Propane')
#   Total Jump: 2
#   Start,End: 4,6
#   Paths:
#     HVAC System Is Shared
#     HVAC System Heating Propane
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#
# ('HVAC System Is Shared', 'HVAC System Shared')
#   Total Jump: 4
#   Start,End: 4,8
#   Paths:
#     HVAC System Is Shared
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     HVAC System Is Shared
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     HVAC System Is Shared
#     HVAC System Shared
#
#
# ('Location EPW', 'Geometry House Size')
#   Total Jump: 2
#   Start,End: 1,3
#   Paths:
#     Location EPW
#     Geometry House Size
#
#     Location EPW
#     Vintage FPL
#     Geometry House Size
#
#
# ('Location EPW', 'Heating Fuel')
#   Total Jump: 2
#   Start,End: 1,3
#   Paths:
#     Location EPW
#     Heating Fuel
#
#     Location EPW
#     Vintage FPL
#     Heating Fuel
#
#
# ('Location EPW', 'Orientation')
#   Total Jump: 2
#   Start,End: 1,3
#   Paths:
#     Location EPW
#     Orientation
#
#
# ('Location EPW', 'Vintage')
#   Total Jump: 2
#   Start,End: 1,3
#   Paths:
#     Location EPW
#     Vintage FPL
#     Vintage
#
#     Location EPW
#     Vintage
#
#
# ('Location Region', 'Clothes Dryer')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Clothes Dryer
#
#
# ('Location Region', 'Cooking Range')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Cooking Range
#
#
# ('Location Region', 'HVAC System Cooling')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Cooling
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#
# ('Location Region', 'HVAC System Heating Electricity')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating Electricity
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#
# ('Location Region', 'HVAC System Heating Fuel Oil')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating Fuel Oil
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#
# ('Location Region', 'HVAC System Heating Natural Gas')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating Natural Gas
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#
# ('Location Region', 'HVAC System Heating None')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating None
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating None
#
#
# ('Location Region', 'HVAC System Heating Other Fuel')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating Other Fuel
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating Other Fuel
#
#
# ('Location Region', 'HVAC System Heating Propane')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heating Propane
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#
# ('Location Region', 'HVAC System Heatpump')
#   Total Jump: 4
#   Start,End: 2,6
#   Paths:
#     Location Region
#     HVAC System Heatpump
#
#     Location Region
#     HVAC System Is Heatpump
#     HVAC System Heatpump
#
#
# ('Location Region', 'HVAC System Is Heatpump')
#   Total Jump: 3
#   Start,End: 2,5
#   Paths:
#     Location Region
#     HVAC System Is Heatpump
#
#
# ('Location Region', 'Infiltration')
#   Total Jump: 3
#   Start,End: 2,5
#   Paths:
#     Location Region
#     Infiltration
#
#
# ('Location Region', 'Insulation Crawlspace')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Crawlspace
#
#
# ('Location Region', 'Insulation Finished Basement')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Finished Basement
#
#
# ('Location Region', 'Insulation Interzonal Floor')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Interzonal Floor
#
#
# ('Location Region', 'Insulation Pier Beam')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Pier Beam
#
#
# ('Location Region', 'Insulation Slab')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Slab
#
#
# ('Location Region', 'Insulation Unfinished Attic')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Unfinished Attic
#
#
# ('Location Region', 'Insulation Unfinished Basement')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Unfinished Basement
#
#
# ('Location Region', 'Insulation Wall')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Insulation Wall
#
#
# ('Location Region', 'Water Heater')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Water Heater
#
#
# ('Location Region', 'Windows')
#   Total Jump: 2
#   Start,End: 2,4
#   Paths:
#     Location Region
#     Windows
#
#
# ('Usage Level', 'Clothes Dryer')
#   Total Jump: 4
#   Start,End: 0,4
#   Paths:
#     Usage Level
#     Clothes Dryer
#
#
# ('Usage Level', 'Cooking Range')
#   Total Jump: 4
#   Start,End: 0,4
#   Paths:
#     Usage Level
#     Cooking Range
#
#
# ('Vintage', 'HVAC System Cooling')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Cooling
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Cooling
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#
#
# ('Vintage', 'HVAC System Heating Electricity')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating Electricity
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Heating Electricity
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Electricity
#
#
# ('Vintage', 'HVAC System Heating Fuel Oil')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating Fuel Oil
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Heating Fuel Oil
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Fuel Oil
#
#
# ('Vintage', 'HVAC System Heating Natural Gas')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating Natural Gas
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Heating Natural Gas
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Natural Gas
#
#
# ('Vintage', 'HVAC System Heating None')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating None
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating None
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating None
#
#
# ('Vintage', 'HVAC System Heating Other Fuel')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating Other Fuel
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating Other Fuel
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Other Fuel
#
#
# ('Vintage', 'HVAC System Heating Propane')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heating Propane
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Heating Propane
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heating Propane
#
#
# ('Vintage', 'HVAC System Heatpump')
#   Total Jump: 3
#   Start,End: 3,6
#   Paths:
#     Vintage
#     HVAC System Heatpump
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Heatpump
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Heatpump
#
#
# ('Vintage', 'HVAC System Is Heatpump')
#   Total Jump: 2
#   Start,End: 3,5
#   Paths:
#     Vintage
#     HVAC System Is Heatpump
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#
#
# ('Vintage', 'HVAC System Shared')
#   Total Jump: 5
#   Start,End: 3,8
#   Paths:
#     Vintage
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Vintage
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Is Heatpump
#     HVAC System Cooling
#     HVAC System Cooling Type
#     HVAC System Shared
#
#     Vintage
#     HVAC System Is Shared
#     HVAC System Shared
#
#     Vintage
#     HVAC System Shared
#
#
# ('Vintage', 'Infiltration')
#   Total Jump: 2
#   Start,End: 3,5
#   Paths:
#     Vintage
#     Geometry Building Floors
#     Infiltration
#
#     Vintage
#     Infiltration
#
#
# 83

# %% [markdown]
# ## Plot the Graph

# %%
G_new = nx.DiGraph()
G_new.add_nodes_from(node_names)
G_new.add_edges_from(edges_new)

scale_x = 1.0
scale_y = 1.0
pos = {}
for i in range(int(longest_path_len)+1):
    idx = np.where(level == i)[0][::-1]
    n_level = len(idx)
    
    j = 1
    for idx_i in idx:
        y = n_level*scale_y*(float(j)/float(n_level)) - n_level/2.0
        x = i*scale_x
        pos[node_names[idx_i]] = (x,y)
        j += 1

draw(G,filename='Dependency_Graph_Full.pdf',show=False) # Full Graph
draw(G_new,filename='Dependency_Graph_Levels.pdf',show=False) # Levels Graph
# Out:
# 'Dependency_Graph_Levels.pdf'
