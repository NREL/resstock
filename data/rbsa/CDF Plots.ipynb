# %% [markdown]
# ###Load data

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from math import ceil, floor
import seaborn as sns

# %%
# %run 'Load RECS Data.ipynb'

# %%
# %run 'Load HECTOR Data.ipynb'

# %%
# %run 'Load HECTOR data_sims.ipynb'

# %%
# %run 'Load Plotting Functions.ipynb'

# %%
sns.set_context("talk")

# %% [markdown]
# ##CDFs

# %%
draw_cdfs(field='site')
draw_cdfs(field='electricity', save=True, xlim=150)
draw_cdfs(field='gas', save=True, xlim=300)

# %% [markdown]
# ##Histograms

# %% [markdown]
# Note how noisy the RECS data is with bin size = 1.

# %%
draw_histograms(field='site', bin_size=1, save=True)

# %%
draw_histograms(field='site', bin_size=10, save=True)
draw_histograms(field='electricity', bin_size=10, save=True)
draw_histograms(field='gas', bin_size=10, save=True)
